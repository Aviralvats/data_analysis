# %%
import pandas as pd

# %%
df=pd.read_csv("netflix_titles.csv")

# %%
df

# %%
df.head()

# %%
df.isnull()

# %%
df.isnull().sum() #now we have two choices either to drop the rows with null values or to fill some value there

# %%
#to drop the rows with null values we use
#df.dropna(inplace=False)#df.head(10).dropna() 
#inplace="True" means that changes will be made in the original dataframe 
df['cast']=df['cast'].fillna("no cast")
df['country']=df['country'].fillna("hello")

# %%
df['type'].value_counts()

# %%
df.head()

# %%
import matplotlib.pyplot as plt

# %%
df['type'].value_counts().plot(kind="bar",color=["red",'yellow'])

# %%
plt.show()

# %%
df.head(1)

# %%
latest_year=df['release_year'].max()

# %%
df[(df['release_year']==df['release_year'].max()) & (df['type']=='Movie')]

# %%
df[(df['release_year']==df['release_year'].max()) & (df['type']=='TV Show')]
#which movies and tv shows are latest released ?

# %%
df.head(1)

# %%
df.head(3)

# %%
df[((df['country'].str.lower())=='france')].value_counts()

# %%
df['country'].value_counts()

# %%
for i in df['country']:
    if str(i).lower().strip()=='united kingdom':
        print(i)

# %%
df

# %%
result=[]
for i in df['title']:
    if i[0].lower()=='a':
        result.append(i)

# %%
empty=[]
for i in range(len(df)):
    title=df['title'].iloc[i]
    if title[0].lower()=='a':
        empty.append(df.iloc[i])
result_df=pd.DataFrame(empty,columns=['title'])

# %%
result_df

# %%
result

# %%
for i in range(len(df)):
    year=df['release_year'].iloc[i]
    if year>2015:
        print(df.iloc[i])

# %%
list_df=[]
for i in range(len(df)):
    year=df['release_year'].iloc[i]
    if year>2015:
       list_df.append(df.iloc[i])
final_df=pd.DataFrame(list_df,columns=df.columns) #columns=df.columns means that we want to keep the same columns as in the original dataframe
final_df

# %%
list_df=[]
for i in range(len(df)):
    year=df['release_year'].iloc[i]
    if year>2015:
       list_df.append(df.iloc[i])
final_df=pd.DataFrame(list_df) #columns=df.columns means that we want to keep the same columns as in the original dataframe
final_df

# %%
df

# %%
df[df['listed_in'].str.contains('Dramas')]

# %%
filter=[]
for i in range(len(df)):
    if 'Dramas' in df['listed_in'].iloc[i]:
        filter.append(df.iloc[i])
final=pd.DataFrame(filter)
final

# %%
len(final)

# %%
df

# %%
import matplotlib.pyplot as plt

# %%
df.head(5)

# %%
df['release_year'].value_counts().plot(kind="pie")

# %%
append=[]
for i in range(len(df)):

    title=df['release_year'].iloc[i]
    if title>2010:
        append.append(df['title'].iloc[i])
        

append

# %%
len(append)

# %%
df[df['release_year'] > 2010]

# %%
df['release_year'].value_counts().idxmax()

# %%
df['release_year'].value_counts().max()

# %%
df.groupby('release_year').size()

# %%
df.groupby('release_year').size().idxmax()

# %%
df.groupby('release_year').size().sort_values(ascending=False)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               no cast  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
movie_country=df['country'].value_counts()

# %%
movie_country.plot(kind="pie")
# Out:
# <Axes: >

# %%
countries=df['country'].str.split(', ')

# %%
all_countries = countries.explode()

# %%
print(all_countries.value_counts())
# Out:
# country
# United States     3689
# India             1046
# hello              831
# United Kingdom     804
# Canada             445
#                   ...
# Sudan                1
# Panama               1
# Uganda               1
# East Germany         1
# Montenegro           1
# Name: count, Length: 128, dtype: int64

# %%
print(df['country'].value_counts())
# Out:
# country
# United States                                    2818
# India                                             972
# hello                                             831
# United Kingdom                                    419
# Japan                                             245
#                                                  ...
# Russia, Spain                                       1
# Croatia, Slovenia, Serbia, Montenegro               1
# Japan, Canada                                       1
# United States, France, South Korea, Indonesia       1
# United Arab Emirates, Jordan                        1
# Name: count, Length: 749, dtype: int64

# %%
all_countries.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='country'>
